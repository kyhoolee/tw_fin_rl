# %%
#!/usr/bin/env python3
import pandas as pd
from pathlib import Path

def check_gdelt_folder(base_dir: str):
    base = Path(base_dir)
    raw_dir = base / "raw"
    flt_dir = base / "filtered"
    man_dir = base / "_manifest"

    print(f"[INFO] Checking folder: {base.resolve()}")

    # 1. Đếm file
    n_raw = len(list(raw_dir.glob("*.parquet"))) if raw_dir.exists() else 0
    n_flt = len(list(flt_dir.glob("*.parquet"))) if flt_dir.exists() else 0
    n_man = len(list(man_dir.glob("*.json"))) if man_dir.exists() else 0
    print(f"  Raw files: {n_raw}")
    print(f"  Filtered files: {n_flt}")
    print(f"  Manifest files: {n_man}")

    # 2. Load thử một số file filtered
    counts = []
    if flt_dir.exists():
        for p in sorted(flt_dir.glob("*.parquet")):
            try:
                df = pd.read_parquet(p)
                counts.append((p.name, len(df)))
            except Exception as e:
                counts.append((p.name, f"ERR {e}"))

    if counts:
        total_rows = sum(c for _, c in counts if isinstance(c, int))
        empty_files = [f for f, c in counts if c == 0]
        print(f"  Total rows in filtered: {total_rows}")
        print(f"  Empty filtered files: {len(empty_files)}")
        if empty_files:
            print("   → " + ", ".join(empty_files[:10]) + (" ..." if len(empty_files) > 10 else ""))
    else:
        print("  (no filtered files to check)")


# ví dụ chạy
check_gdelt_folder("../../work/data/gdelt_debug_hardfix_split")
# Out:
# [INFO] Checking folder: /home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split
#   Raw files: 12
#   Filtered files: 14
#   Manifest files: 12
#   Total rows in filtered: 1249
#   Empty filtered files: 1
#    → gdelt_filtered_BNB_2025-09-02_0600_2300_9632115cff6b661a.parquet

# %%
#!/usr/bin/env python3
"""
Quick check for MERGED parquet files:
- Tự động tìm các file có 'merged' trong tên hoặc nằm trong thư mục 'merged/'
- Đếm số dòng mà không load toàn bộ (dùng pyarrow ParquetFile)
- In thống kê: số file, tổng số dòng, số file rỗng, liệt kê vài file rỗng

Usage:
  python check_merged_parquet.py /path/to/base_dir
  # tuỳ chọn: chỉ định glob riêng
  python check_merged_parquet.py /data --glob "**/merged/*.parquet"
"""
import sys
from pathlib import Path

try:
    import pyarrow.parquet as pq
except ImportError:
    print("[ERROR] Please install pyarrow: pip install pyarrow", file=sys.stderr)
    sys.exit(1)

def count_rows_parquet(fp: Path) -> int:
    try:
        pf = pq.ParquetFile(fp)
        md = pf.metadata
        return sum(md.row_group(i).num_rows for i in range(md.num_row_groups))
    except Exception as e:
        print(f"[WARN] Can't read {fp}: {e}")
        return -1  # unreadable

def looks_merged(p: Path) -> bool:
    name_has = 'merged' in p.name.lower()
    folder_has = any(part.lower() == 'merged' for part in p.parts)
    return name_has or folder_has

def find_merged_files(base: Path, custom_glob: str | None) -> list[Path]:
    if custom_glob:
        return sorted(base.glob(custom_glob))
    # Mặc định: hai pattern phổ biến
    found = set()
    for pat in ("**/*merged*.parquet", "**/merged/*.parquet"):
        for fp in base.glob(pat):
            found.add(fp)
    # Fallback: toàn bộ parquet rồi lọc bằng looks_merged
    if not found:
        found = {p for p in base.glob("**/*.parquet") if looks_merged(p)}
    return sorted(found)

def main():
    if len(sys.argv) < 2:
        print("Usage: python check_merged_parquet.py <base_dir> [--glob \"**/merged/*.parquet\"]")
        sys.exit(1)

    base = Path(sys.argv[1]).expanduser().resolve()
    custom_glob = None
    if len(sys.argv) >= 4 and sys.argv[2] == "--glob":
        custom_glob = sys.argv[3]

    merged_files = find_merged_files(base, custom_glob)
    print(f"[INFO] Checking MERGED under: {base}")
    print(f"  Merged files: {len(merged_files)}")

    total_rows = 0
    empty_names = []
    unreadable = 0

    for fp in merged_files:
        rows = count_rows_parquet(fp)
        if rows < 0:
            unreadable += 1
            continue
        total_rows += rows
        if rows == 0 and len(empty_names) < 30:
            empty_names.append(fp.name)

    print(f"  Total rows in merged: {total_rows}")
    print(f"  Empty merged files: {len(empty_names)}")
    if empty_names:
        print("   → " + ", ".join(empty_names) + (" ..." if len(empty_names) == 30 else ""))
    if unreadable:
        print(f"  [WARN] Unreadable merged files: {unreadable}")

import sys

# giả lập lệnh:
# python check_merged_parquet.py /home/kylh/phd/tw_fin_rl/work/data/gdelt_full_hardfix_split
sys.argv = [
    "check_merged_parquet.py",
    "/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split"
]

# gọi hàm main trong notebook
main()
# Out:
# [INFO] Checking MERGED under: /home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split
#   Merged files: 2
#   Total rows in merged: 970
#   Empty merged files: 0

# %%
import pandas as pd
from pathlib import Path

def analyze_merged(base_dir: str, glob_pat: str = "**/*merged*.parquet"):
    base = Path(base_dir).expanduser().resolve()
    files = sorted(base.glob(glob_pat))

    print(f"[INFO] Loading MERGED files from: {base}")
    # print list files 
    print("FILES:: ", files)

    dfs = []
    for fp in files:
        print(f"[INFO] Loading {fp} ...")
        try:
            df = pd.read_parquet(fp)
            dfs.append(df)
        except Exception as e:
            print(f"  [WARN] Can't read {fp}: {e}")
    if not dfs:
        return None
    
    data = pd.concat(dfs, ignore_index=True)
    
    # Xác định token từ cột 'symbol' (nếu có)
    if "symbol" in data.columns:
        tokens = data["symbol"].unique().tolist()
    else:
        # fallback: đoán từ text
        tokens = ["BTC","ETH","BNB","SOL"]

    results = {}
    for token in tokens:
        # chọn subset theo cột 'symbol'
        if "symbol" in data.columns:
            sub = data[data["symbol"] == token]
        else:
            mask = data["text"].str.contains(token, case=False, na=False)
            sub = data[mask]
        
        if sub.empty:
            continue

        results[token] = {
            "n_articles": len(sub),
            "time_range": (sub["date"].min(), sub["date"].max()) if "date" in sub.columns else None,
            "sources": sub["source"].nunique() if "source" in sub.columns else None,
            "langs": sub["lang"].value_counts().head(5).to_dict() if "lang" in sub.columns else None,
            "sample_titles": sub["title"].dropna().head(3).tolist() if "title" in sub.columns else None
        }
    return results, data

# Chạy:
stats, df_all = analyze_merged("/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split")

import pprint
pprint.pprint(stats)
# Out:
# [INFO] Loading MERGED files from: /home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split
# FILES::  [PosixPath('/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_filtered_merged_2025-09-01_2025-09-03.parquet'), PosixPath('/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_raw_merged_2025-09-01_2025-09-03.parquet')]
# [INFO] Loading /home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_filtered_merged_2025-09-01_2025-09-03.parquet ...
# [INFO] Loading /home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_raw_merged_2025-09-01_2025-09-03.parquet ...
# {'BNB': {'langs': None,
#          'n_articles': 7,
#          'sample_titles': ['Binance Invests $53M in Mexican Fintech Expansion '
#                            'Through New Regulated Platform',
#                            'Why XRP , BNB and Solana traders brace for a '
#                            'bearish September',
#                            'BNB Slips Below $860 as Resistance Holds and '
#                            'Traders Brace for U . S . Jobs Data'],
#          'sources': None,
#          'time_range': (datetime.date(2025, 9, 1), datetime.date(2025, 9, 3))},
#  'BTC': {'langs': None,
#          'n_articles': 131,
#          'sample_titles': ['InFocus launches digital ventures strategy with '
#                            'Mythos Group to push into Blockchain , AI and '
#                            'Bitcoin',
#                            'InFocus launches digital ventures strategy with '
#                            'Mythos Group to push into Blockchain , AI and '
#                            'Bitcoin',
#                            'InFocus launches digital ventures strategy with '
#                            'Mythos Group to push into Blockchain , AI and '
#                            'Bitcoin'],
#          'sources': None,
#          'time_range': (datetime.date(2025, 9, 1), datetime.date(2025, 9, 3))},
#  'ETH': {'langs': None,
#          'n_articles': 40,
#          'sample_titles': ['Ethereum Price Dips As OG Whale Sells $400M BTC '
#                            'For ETH',
#                            'Ethereum Demand Stays Strong As Exchange Reserves '
#                            'Keep Falling – Details',
#                            'Unlock Daily Crypto Earnings on XRP , DOGE , ETH , '
#                            'and BTC : Quid Miner Cloud Mining Your Passive '
#                            'Income Strategy for 2025'],
#          'sources': None,
#          'time_range': (datetime.date(2025, 9, 1), datetime.date(2025, 9, 3))},
#  'SOL': {'langs': None,
#          'n_articles': 13,
#          'sample_titles': ['Solana Real World Assets Hit $500M All - Time High '
#                            ': Will SOL Price Hit $300 in September ? ',
#                            'Cryptocurrencies Price Prediction : Ethereum , '
#                            'Bitcoin & Solana – European Wrap 1 September',
#                            'Why XRP , BNB and Solana traders brace for a '
#                            'bearish September'],
#          'sources': None,
#          'time_range': (datetime.date(2025, 9, 1), datetime.date(2025, 9, 3))}}

# %%
import pandas as pd

# Đường dẫn file
path = "/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_raw_merged_2025-09-01_2025-09-03.parquet"

# Đọc file parquet
df = pd.read_parquet(path)

# Thông tin cơ bản
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

# Hiển thị sample
print(df.sample(5, random_state=42))
# Out:
# Shape: (779, 10)
# Columns: ['title', 'url', 'domain', 'language', 'seendate', 'socialimage', 'sourcecountry', 'isduplicate', 'day', 'symbol_req']
#                                                  title  \
# 595  Dollar drops against peers , euro gains after ...
# 587  Trump - backed bitcoin company begins trading ...
# 543  Wall Street steadies itself as Alphabet rallie...
# 644          American Bitcoin to debut on Nasdaq today
# 487  Galxe One Day Volume Reaches $61 . 28 Thousand...
#
#                                                    url               domain  \
# 595  https://www.marketscreener.com/news/dollar-dro...   marketscreener.com
# 587  https://www.kob.com/ap-top-news/trump-backed-b...              kob.com
# 543  https://www.journal-news.com/news/nation-world...     journal-news.com
# 644              https://biztoc.com/x/935ce7dac9b5d02b           biztoc.com
# 487  https://www.themarketsdaily.com/2025/09/02/gal...  themarketsdaily.com
#
#     language                  seendate  \
# 595  English 2025-09-03 17:00:00+00:00
# 587  English 2025-09-03 17:45:00+00:00
# 543  English 2025-09-03 21:45:00+00:00
# 644  English 2025-09-03 13:30:00+00:00
# 487  English 2025-09-02 11:30:00+00:00
#
#                                            socialimage  sourcecountry  \
# 595  https://cdn.zonebourse.com/static/resize/0/0/i...
# 587  https://www.kob.com/wp-content/uploads/apimg/2...  United States
# 543  https://www.journal-news.com/resizer/v2/3RNLOH...  United States
# 644     https://biztoc.com/cdn/935ce7dac9b5d02b_s.webp
# 487                                                     United States
#
#     isduplicate         day symbol_req
# 595        None  2025-09-03        BTC
# 587        None  2025-09-03        BTC
# 543        None  2025-09-03        BTC
# 644        None  2025-09-03        BTC
# 487        None  2025-09-02        ETH

# %%
import pandas as pd
from tabulate import tabulate

# Đường dẫn file
path = "/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_raw_merged_2025-09-01_2025-09-03.parquet"

# Đọc file parquet
df = pd.read_parquet(path)

# Lấy sample
sample = df.sample(5, random_state=42)

# In bảng đẹp
print(tabulate(sample, headers="keys", tablefmt="pretty", showindex=True))
# Out:
# +-----+-----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+---------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------+------------+------------+
# |     |                                          title                                          |                                                                                url                                                                                 |       domain        | language |         seendate          |                                                                       socialimage                                                                       | sourcecountry | isduplicate |    day     | symbol_req |
# +-----+-----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+---------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------+------------+------------+
# | 595 |               Dollar drops against peers , euro gains after US jobs data                |                           https://www.marketscreener.com/news/dollar-drops-against-peers-euro-gains-after-us-jobs-data-ce7d59dbda89f026                            | marketscreener.com  | English  | 2025-09-03 17:00:00+00:00 |         https://cdn.zonebourse.com/static/resize/0/0/images/reuters/2025-09/2025-09-03T010437Z_1_LYNXMPEL8200W_RTROPTP_4_BUSINESS-CURRENCY.JPG          |               |             | 2025-09-03 |    BTC     |
# | 587 |                 Trump - backed bitcoin company begins trading on Nasdaq                 |                                       https://www.kob.com/ap-top-news/trump-backed-bitcoin-company-begins-trading-on-nasdaq/                                       |       kob.com       | English  | 2025-09-03 17:45:00+00:00 |                                 https://www.kob.com/wp-content/uploads/apimg/2025/09/Hong_Kong_Bitcoin_Trump_58707.jpg                                  | United States |             | 2025-09-03 |    BTC     |
# | 543 | Wall Street steadies itself as Alphabet rallies and pressure eases from the bond market | https://www.journal-news.com/news/nation-world/wall-street-steadies-itself-as-alphabet-rallies-and-pressure-eases-from-the-bond-market/OKOSO7XPNJMS5K34GI4W3QVHMY/ |  journal-news.com   | English  | 2025-09-03 21:45:00+00:00 | https://www.journal-news.com/resizer/v2/3RNLOHKIZJAMNHR2LSNGVLICIE.jpg?auth=2d95ecbcbdaad043126718f9a4f3ce91c2d47cea09524d81bb3ece6fb54b1304&smart=true | United States |             | 2025-09-03 |    BTC     |
# | 644 |                        American Bitcoin to debut on Nasdaq today                        |                                                               https://biztoc.com/x/935ce7dac9b5d02b                                                                |     biztoc.com      | English  | 2025-09-03 13:30:00+00:00 |                                                     https://biztoc.com/cdn/935ce7dac9b5d02b_s.webp                                                      |               |             | 2025-09-03 |    BTC     |
# | 487 |                 Galxe One Day Volume Reaches $61 . 28 Thousand ( GAL )                  |                                  https://www.themarketsdaily.com/2025/09/02/galxe-one-day-volume-reaches-61-28-thousand-gal.html                                   | themarketsdaily.com | English  | 2025-09-02 11:30:00+00:00 |                                                                                                                                                         | United States |             | 2025-09-02 |    ETH     |
# +-----+-----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+---------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------+------------+------------+

# %%
import pandas as pd
from tabulate import tabulate

# Load dữ liệu
path = "/home/kylh/phd/tw_fin_rl/work/data/gdelt_debug_hardfix_split/filtered/gdelt_raw_merged_2025-09-01_2025-09-03.parquet"

df = pd.read_parquet(path)

# Các token cần lọc
tokens = ["BTC", "BNB", "ETH", "SOL"]

for sym in tokens:
    subset = df[df["symbol_req"] == sym]
    print(f"\n=== {sym} | total={len(subset)} ===")
    if len(subset) == 0:
        print("⚠️ Không có dữ liệu.")
        continue
    
    # Lấy 3 dòng đầu và 3 dòng cuối
    sample = pd.concat([subset.head(3), subset.tail(3)])
    
    # In bảng pretty
    print(tabulate(sample, headers="keys", tablefmt="pretty", showindex=True))
# Out:
# === BTC | total=501 ===
# +-----+--------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------+------------+------------+
# |     |                                                                         title                                                                          |                                                                                 url                                                                                  |       domain        | language |         seendate          |                                                                                 socialimage                                                                                 | sourcecountry | isduplicate |    day     | symbol_req |
# +-----+--------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------+---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------+------------+------------+
# |  0  |                                        8 Reasons Why You Should Consider Investing In Cryptocurrency This Year                                         |                            https://rocklandtimes.com/2025/09/01/8-reasons-why-you-should-consider-investing-in-cryptocurrency-this-year/                             |  rocklandtimes.com  | English  | 2025-09-01 21:30:00+00:00 |                                                  https://rocklandtimes.com/wp-content/uploads/2025/09/Picture1-700x467.png                                                  | United States |             | 2025-09-01 |    BTC     |
# |  1  |                              Solana Real World Assets Hit $500M All - Time High : Will SOL Price Hit $300 in September ?                               |                           https://www.coinspeaker.com/solana-real-world-assets-hit-500m-all-time-high-will-sol-price-hit-300-in-september/                           |   coinspeaker.com   | English  | 2025-09-01 21:30:00+00:00 |                                             https://www.coinspeaker.com/wp-content/uploads/2025/09/stock-image_optimized-21.jpg                                             | United States |             | 2025-09-01 |    BTC     |
# |  2  |                         InFocus launches digital ventures strategy with Mythos Group to push into Blockchain , AI and Bitcoin                          |             http://www.sydneysun.com/news/278545240/infocus-launches-digital-ventures-strategy-with-mythos-group-to-push-into-blockchain-ai-and-bitcoin              |    sydneysun.com    | English  | 2025-09-01 21:30:00+00:00 |                                                                                                                                                                             |   Australia   |             | 2025-09-01 |    BTC     |
# | 702 | Ray Dalio Warns America Of A Debt - Induced  Heart - Attack  In The Near Future :  Three Years , Give Or Take A Year Or Two  - Intel ( NASDAQ : INTC ) | https://www.benzinga.com/markets/macro-economic-events/25/09/47466125/ray-dalio-warns-america-of-debt-induced-heart-attack-in-near-future-give-or-take-a-year-or-two |    benzinga.com     | English  | 2025-09-03 07:15:00+00:00 |                               https://cdn.benzinga.com/files/images/story/2025/09/03/Stock-Market-Problems-In-Usa--Statue-Of-.jpeg?&fit=crop                                | United States |             | 2025-09-03 |    BTC     |
# | 703 |                                          Bitcoin , Ethereum and XRP Hold Steady as  Red September  Kicks Off                                           |                                            https://finance.yahoo.com/news/bitcoin-ethereum-xrp-hold-steady-190400592.html                                            |  finance.yahoo.com  | English  | 2025-09-03 06:45:00+00:00 | https://s.yimg.com/ny/api/res/1.2/ba4fXScLno2NPp_1.TZ_jw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en