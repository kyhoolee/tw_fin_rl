# %%
#!/usr/bin/env python3
import pandas as pd
from pathlib import Path

def check_gdelt_folder(base_dir: str):
    base = Path(base_dir)
    raw_dir = base / "raw"
    flt_dir = base / "filtered"
    man_dir = base / "_manifest"

    print(f"[INFO] Checking folder: {base.resolve()}")

    # 1. Đếm file
    n_raw = len(list(raw_dir.glob("*.parquet"))) if raw_dir.exists() else 0
    n_flt = len(list(flt_dir.glob("*.parquet"))) if flt_dir.exists() else 0
    n_man = len(list(man_dir.glob("*.json"))) if man_dir.exists() else 0
    print(f"  Raw files: {n_raw}")
    print(f"  Filtered files: {n_flt}")
    print(f"  Manifest files: {n_man}")

    # 2. Load thử một số file filtered
    counts = []
    if flt_dir.exists():
        for p in sorted(flt_dir.glob("*.parquet")):
            try:
                df = pd.read_parquet(p)
                counts.append((p.name, len(df)))
            except Exception as e:
                counts.append((p.name, f"ERR {e}"))

    if counts:
        total_rows = sum(c for _, c in counts if isinstance(c, int))
        empty_files = [f for f, c in counts if c == 0]
        print(f"  Total rows in filtered: {total_rows}")
        print(f"  Empty filtered files: {len(empty_files)}")
        if empty_files:
            print("   → " + ", ".join(empty_files[:10]) + (" ..." if len(empty_files) > 10 else ""))
    else:
        print("  (no filtered files to check)")


# ví dụ chạy
check_gdelt_folder("../../work/data/gdelt_0024_hardfix_split")
# Out:
# [INFO] Checking folder: /home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split
#   Raw files: 7400
#   Filtered files: 7402
#   Manifest files: 7400
#   Total rows in filtered: 1034810
#   Empty filtered files: 1383
#    → gdelt_filtered_BNB_2020-08-11_0000_2359_c82d5e939996e9de.parquet, gdelt_filtered_BNB_2020-08-12_0000_2359_dafebb247b941de0.parquet, gdelt_filtered_BNB_2020-08-13_0000_2359_4cee89611acc1813.parquet, gdelt_filtered_BNB_2020-08-14_0000_2359_072290422ae53524.parquet, gdelt_filtered_BNB_2020-08-16_0000_2359_b673d5dabc6ccfe0.parquet, gdelt_filtered_BNB_2020-08-17_0000_2359_2657bab7e13c8043.parquet, gdelt_filtered_BNB_2020-08-18_0000_2359_0eb6333438764dd6.parquet, gdelt_filtered_BNB_2020-08-19_0000_2359_c4e08f75960d4d53.parquet, gdelt_filtered_BNB_2020-08-20_0000_2359_e1c73a6a250ecbc7.parquet, gdelt_filtered_BNB_2020-08-21_0000_2359_089237c4219ec825.parquet ...

# %%
#!/usr/bin/env python3
"""
Quick check for MERGED parquet files:
- Tự động tìm các file có 'merged' trong tên hoặc nằm trong thư mục 'merged/'
- Đếm số dòng mà không load toàn bộ (dùng pyarrow ParquetFile)
- In thống kê: số file, tổng số dòng, số file rỗng, liệt kê vài file rỗng

Usage:
  python check_merged_parquet.py /path/to/base_dir
  # tuỳ chọn: chỉ định glob riêng
  python check_merged_parquet.py /data --glob "**/merged/*.parquet"
"""
import sys
from pathlib import Path

try:
    import pyarrow.parquet as pq
except ImportError:
    print("[ERROR] Please install pyarrow: pip install pyarrow", file=sys.stderr)
    sys.exit(1)

def count_rows_parquet(fp: Path) -> int:
    try:
        pf = pq.ParquetFile(fp)
        md = pf.metadata
        return sum(md.row_group(i).num_rows for i in range(md.num_row_groups))
    except Exception as e:
        print(f"[WARN] Can't read {fp}: {e}")
        return -1  # unreadable

def looks_merged(p: Path) -> bool:
    name_has = 'merged' in p.name.lower()
    folder_has = any(part.lower() == 'merged' for part in p.parts)
    return name_has or folder_has

def find_merged_files(base: Path, custom_glob: str | None) -> list[Path]:
    if custom_glob:
        return sorted(base.glob(custom_glob))
    # Mặc định: hai pattern phổ biến
    found = set()
    for pat in ("**/*merged*.parquet", "**/merged/*.parquet"):
        for fp in base.glob(pat):
            found.add(fp)
    # Fallback: toàn bộ parquet rồi lọc bằng looks_merged
    if not found:
        found = {p for p in base.glob("**/*.parquet") if looks_merged(p)}
    return sorted(found)

def main():
    if len(sys.argv) < 2:
        print("Usage: python check_merged_parquet.py <base_dir> [--glob \"**/merged/*.parquet\"]")
        sys.exit(1)

    base = Path(sys.argv[1]).expanduser().resolve()
    custom_glob = None
    if len(sys.argv) >= 4 and sys.argv[2] == "--glob":
        custom_glob = sys.argv[3]

    merged_files = find_merged_files(base, custom_glob)
    print(f"[INFO] Checking MERGED under: {base}")
    print(f"  Merged files: {len(merged_files)}")

    total_rows = 0
    empty_names = []
    unreadable = 0

    for fp in merged_files:
        rows = count_rows_parquet(fp)
        if rows < 0:
            unreadable += 1
            continue
        total_rows += rows
        if rows == 0 and len(empty_names) < 30:
            empty_names.append(fp.name)

    print(f"  Total rows in merged: {total_rows}")
    print(f"  Empty merged files: {len(empty_names)}")
    if empty_names:
        print("   → " + ", ".join(empty_names) + (" ..." if len(empty_names) == 30 else ""))
    if unreadable:
        print(f"  [WARN] Unreadable merged files: {unreadable}")

import sys

# giả lập lệnh:
# python check_merged_parquet.py /home/kylh/phd/tw_fin_rl/work/data/gdelt_full_hardfix_split
sys.argv = [
    "check_merged_parquet.py",
    "/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split"
]

# gọi hàm main trong notebook
main()
# Out:
# [INFO] Checking MERGED under: /home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split
#   Merged files: 2
#   Total rows in merged: 846797
#   Empty merged files: 0

# %%
import pandas as pd
from pathlib import Path

def analyze_merged(base_dir: str, glob_pat: str = "**/*merged*.parquet"):
    base = Path(base_dir).expanduser().resolve()
    files = sorted(base.glob(glob_pat))

    print(f"[INFO] Loading MERGED files from: {base}")
    # print list files 
    print("FILES:: ", files)

    dfs = []
    for fp in files:
        print(f"[INFO] Loading {fp} ...")
        try:
            df = pd.read_parquet(fp)
            dfs.append(df)
        except Exception as e:
            print(f"  [WARN] Can't read {fp}: {e}")
    if not dfs:
        return None
    
    data = pd.concat(dfs, ignore_index=True)
    
    # Xác định token từ cột 'symbol' (nếu có)
    if "symbol" in data.columns:
        tokens = data["symbol"].unique().tolist()
    else:
        # fallback: đoán từ text
        tokens = ["BTC","ETH","BNB","SOL"]

    results = {}
    for token in tokens:
        # chọn subset theo cột 'symbol'
        if "symbol" in data.columns:
            sub = data[data["symbol"] == token]
        else:
            mask = data["text"].str.contains(token, case=False, na=False)
            sub = data[mask]
        
        if sub.empty:
            continue

        results[token] = {
            "n_articles": len(sub),
            "time_range": (sub["date"].min(), sub["date"].max()) if "date" in sub.columns else None,
            "sources": sub["source"].nunique() if "source" in sub.columns else None,
            "langs": sub["lang"].value_counts().head(5).to_dict() if "lang" in sub.columns else None,
            "sample_titles": sub["title"].dropna().head(3).tolist() if "title" in sub.columns else None
        }
    return results, data

# Chạy:
stats, df_all = analyze_merged("/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split")

import pprint
pprint.pprint(stats)
# Out:
# [INFO] Loading MERGED files from: /home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split
# FILES::  [PosixPath('/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_filtered_merged_2020-08-11_2025-09-03.parquet'), PosixPath('/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_raw_merged_2020-08-11_2025-09-03.parquet')]
# [INFO] Loading /home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_filtered_merged_2020-08-11_2025-09-03.parquet ...
# [INFO] Loading /home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_raw_merged_2020-08-11_2025-09-03.parquet ...
# {'BNB': {'langs': None,
#          'n_articles': 6719,
#          'sample_titles': ['DEX Aggregator 1inch Raises $2 . 8M From Binance '
#                            'Labs , Galaxy Digital and More',
#                            'Price Analysis 8 / 14 : BTC , ETH , XRP , LINK , '
#                            'BCH , BSV , LTC , ADA , BNB , CRO',
#                            'Binance Coin to challenge its strongest resistance '
#                            'yet again'],
#          'sources': None,
#          'time_range': (datetime.date(2020, 8, 11), datetime.date(2025, 9, 3))},
#  'BTC': {'langs': None,
#          'n_articles': 108474,
#          'sample_titles': ['Dairy farmer  blackmailed Tesco for £1 . 4m in '
#                            'bitcoin  | News',
#                            'Top 3 Coins Price Prediction Bitcoin , Ethereum '
#                            'and Ripple : All three coins face strong '
#                            'resistance levels – Confluence Detector',
#                            'Biz Analytics Co . To Spend $500M On Bitcoin , '
#                            'Stock Buybacks'],
#          'sources': None,
#          'time_range': (datetime.date(2020, 8, 11), datetime.date(2025, 9, 3))},
#  'ETH': {'langs': None,
#          'n_articles': 26050,
#          'sample_titles': ['Top 3 Coins Price Prediction Bitcoin , Ethereum '
#                            'and Ripple : All three coins face strong '
#                            'resistance levels – Confluence Detector',
#                            'Cryptocurrency Market News : Ethereum slides below '
#                            '$380 as the market starts to lose its positive '
#                            'sentiment',
#                            'Alt 5 Sigma , Inc .: ALT 5 Sigma Digital '
#                            'Instrument Market Summary for BTC , ETH , LTC , '
#                            'BCH'],
#          'sources': None,
#          'time_range': (datetime.date(2020, 8, 11), datetime.date(2025, 9, 3))},
#  'SOL': {'langs': None,
#          'n_articles': 6789,
#          'sample_titles': ['Coinbase Custody Offers Staking for Solana '
#                            'alongside Bison Trails',
#                            'Tether ( USDt ) Launches As First Stablecoin On '
#                            'Solana , An Ultra High - Speed Layer 1 Blockchain '
#                            '- Technical Collaboration Enables Institutions To '
#                            'Trade USDt At Nasdaq Speeds',
#                            'Soul Pattinson ( ASX : SOL ) share price higher '
#                            'after full year results release'],
#          'sources': None,
#          'time_range': (datetime.date(2020, 8, 28), datetime.date(2025, 9, 3))}}

# %%
import pandas as pd

# Đường dẫn file
path = "/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_filtered_merged_2020-08-11_2025-09-03.parquet"

# Đọc file parquet
df = pd.read_parquet(path)

# Thông tin cơ bản
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

# Hiển thị sample
print(df.sample(5, random_state=42))
# Out:
# Shape: (148032, 12)
# Columns: ['title', 'url', 'domain', 'language', 'seendate', 'socialimage', 'sourcecountry', 'isduplicate', 'symbol', 'date', 'day', 'symbol_req']
#                                                    title  \
# 12734  Millions of Aussies investing in cryptocurrenc...
# 15832  Bitcoin Evolution Review : Comprehensive Sign ...
# 33045  Top 3 Price Prediction Bitcoin , Ethereum , Ri...
# 32896  Bitcoin Will Hit All - Time Highs Again This Y...
# 23895  Second - biggest cryptocurrency Ethereum break...
#
#                                                      url  \
# 12734  https://www.goldcoastbulletin.com.au/business/...
# 15832  https://www.londonmercury.com/news/267926094/b...
# 33045  https://www.fxstreet.com/cryptocurrencies/news...
# 32896  https://www.wtma.com/news/bitcoin-will-hit-all...
# 23895  https://www.dawn.com/news/1623096/second-bigge...
#
#                          domain language                  seendate  \
# 12734  goldcoastbulletin.com.au  English 2021-02-05 10:15:00+00:00
# 15832         londonmercury.com  English 2021-02-24 22:00:00+00:00
# 33045              fxstreet.com  English 2021-07-22 00:30:00+00:00
# 32896                  wtma.com  English 2021-07-22 22:45:00+00:00
# 23895                  dawn.com  English 2021-05-10 13:15:00+00:00
#
#                                              socialimage   sourcecountry  \
# 12734  https://cdn.newsapi.com.au/image/v1/194e2b4802...       Australia
# 15832                                                     United Kingdom
# 33045  https://editorial.fxstreet.com/images/Markets/...           China
# 32896                                                      United States
# 23895                                                           Pakistan
#
#       isduplicate symbol        date         day symbol_req
# 12734        None    BTC  2021-02-05  2021-02-05        ETH
# 15832        None    BTC  2021-02-24  2021-02-24        BTC
# 33045        None    ETH  2021-07-22  2021-07-22        ETH
# 32896        None    BTC  2021-07-22  2021-07-22        BTC
# 23895        None    ETH  2021-05-10  2021-05-10        ETH

# %%
import pandas as pd
from tabulate import tabulate

# Đường dẫn file
path = "/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_filtered_merged_2020-08-11_2025-09-03.parquet"

# Đọc file parquet
df = pd.read_parquet(path)

# Lấy sample
sample = df.sample(5, random_state=42)

# In bảng đẹp
print(tabulate(sample, headers="keys", tablefmt="pretty", showindex=True))
# Out:
# +-------+---------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------+---------------------------+-------------------------------------------------------------------------------------------------------------------+----------------+-------------+--------+------------+------------+------------+
# |       |                                                           title                                                           |                                                                                                                  url                                                                                                                   |          domain          | language |         seendate          |                                                    socialimage                                                    | sourcecountry  | isduplicate | symbol |    date    |    day     | symbol_req |
# +-------+---------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------+---------------------------+-------------------------------------------------------------------------------------------------------------------+----------------+-------------+--------+------------+------------+------------+
# | 12734 |                               Millions of Aussies investing in cryptocurrency like Bitcoin                                | https://www.goldcoastbulletin.com.au/business/australians-are-investing-in-cryptocurrency-like-bitcoin-due-to-fomo-and-its-increasing-value/news-story/e19861e1dea7a28b8a59310e04fd3d08?nk=d0c9864800d49e6ae96e584cb921ab73-1612519389 | goldcoastbulletin.com.au | English  | 2021-02-05 10:15:00+00:00 |                       https://cdn.newsapi.com.au/image/v1/194e2b48022a664e78758b04fe06910e                        |   Australia    |             |  BTC   | 2021-02-05 | 2021-02-05 |    ETH     |
# | 15832 |                            Bitcoin Evolution Review : Comprehensive Sign Up Guide For The App                             |                                                             https://www.londonmercury.com/news/267926094/bitcoin-evolution-review--comprehensive-sign-up-guide-for-the-app                                                             |    londonmercury.com     | English  | 2021-02-24 22:00:00+00:00 |                                                                                                                   | United Kingdom |             |  BTC   | 2021-02-24 | 2021-02-24 |    BTC     |
# | 33045 | Top 3 Price Prediction Bitcoin , Ethereum , Ripple : Crypto market starts its engines , as ETH targets best day since May |                             https://www.fxstreet.com/cryptocurrencies/news/top-3-price-prediction-bitcoin-ethereum-ripple-crypto-market-starts-its-engines-as-eth-targets-best-day-since-may-202107211712                              |       fxstreet.com       | English  | 2021-07-22 00:30:00+00:00 | https://editorial.fxstreet.com/images/Markets/Currencies/Digital%20Currencies/Bitcoin/bitcoins-33758372_Large.jpg |     China      |             |  ETH   | 2021-07-22 | 2021-07-22 |    ETH     |
# | 32896 |                    Bitcoin Will Hit All - Time Highs Again This Year , Crypto Is the Inevitable Future                    |                                                               https://www.wtma.com/news/bitcoin-will-hit-all-time-highs-again-this-year-crypto-is-the-inevitable-future/                                                               |         wtma.com         | English  | 2021-07-22 22:45:00+00:00 |                                                                                                                   | United States  |             |  BTC   | 2021-07-22 | 2021-07-22 |    BTC     |
# | 23895 |                    Second - biggest cryptocurrency Ethereum breaks $4 , 000 to hit record high - World                    |                                                                https://www.dawn.com/news/1623096/second-biggest-cryptocurrency-ethereum-breaks-4000-to-hit-record-high                                                                 |         dawn.com         | English  | 2021-05-10 13:15:00+00:00 |                                                                                                                   |    Pakistan    |             |  ETH   | 2021-05-10 | 2021-05-10 |    ETH     |
# +-------+---------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------+---------------------------+-------------------------------------------------------------------------------------------------------------------+----------------+-------------+--------+------------+------------+------------+

# %%
import pandas as pd
from tabulate import tabulate

# Load dữ liệu
path = "/home/kylh/phd/tw_fin_rl/work/data/gdelt_0024_hardfix_split/filtered/gdelt_filtered_merged_2020-08-11_2025-09-03.parquet"

df = pd.read_parquet(path)

# Các token cần lọc
tokens = ["BTC", "BNB", "ETH", "SOL"]

for sym in tokens:
    subset = df[df["symbol_req"] == sym]
    print(f"\n=== {sym} | total={len(subset)} ===")
    if len(subset) == 0:
        print("⚠️ Không có dữ liệu.")
        continue
    
    # Lấy 3 dòng đầu và 3 dòng cuối
    sample = pd.concat([subset.head(3), subset.tail(3)])
    
    # In bảng pretty
    print(tabulate(sample, headers="keys", tablefmt="pretty", showindex=True))
# Out:
# === BTC | total=114830 ===
# +--------+------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+----------+---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+--------+------------+------------+------------+
# |        |                                                               title                                                                |                                                                           url                                                                           |      domain       | language |         seendate          |                                                                                 socialimage                                                                                 | sourcecountry  | isduplicate | symbol |    date    |    day     | symbol_req |
# +--------+------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+----------+---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+--------+------------+------------+------------+
# |   0    |                                   Dairy farmer  blackmailed Tesco for £1 . 4m in bitcoin  | News                                   |                          https://www.thetimes.co.uk/edition/news/dairy-farmer-blackmailed-tesco-for-1-4m-in-bitcoin-c2wgwrlmx                           |  thetimes.co.uk   | English  | 2020-08-11 23:30:00+00:00 |          https://www.thetimes.co.uk/imageserver/image/%2Fmethode%2Ftimes%2Fprod%2Fweb%2Fbin%2F232fcc8a-dc06-11ea-8d9c-6a97b944a97b.jpg?crop=5058%2C2845%2C0%2C263           | United Kingdom |             |  BTC   | 2020-08-11 | 2020-08-11 |    BTC     |
