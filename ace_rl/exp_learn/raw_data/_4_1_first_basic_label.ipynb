# %%
from pathlib import Path
import xarray as xr

root = Path("../../../work/processed/binance").expanduser()
cached_cube = xr.open_zarr(
    (root / "data" / "zarr_cube_intersection").as_posix(),
    consolidated=True,  # flip to False if you ever disable consolidation
)
print(cached_cube)

cube = cached_cube
# Out:
# <xarray.Dataset> Size: 501MB
# Dimensions:  (feature: 9, time: 2662909, symbol: 4)
# Coordinates:
#   * feature  (feature) <U13 468B 'Open' 'High' ... 'TakerBuyQuote'
#   * symbol   (symbol) object 32B 'BTCUSDT' 'ETHUSDT' 'BNBUSDT' 'SOLUSDT'
#   * time     (time) datetime64[ns] 21MB 2020-08-11T06:00:00 ... 2025-09-04T11...
# Data variables:
#     mask     (time, symbol, feature) bool 96MB dask.array<chunksize=(16384, 4, 9), meta=np.ndarray>
#     values   (time, symbol, feature) float32 383MB dask.array<chunksize=(16384, 4, 9), meta=np.ndarray>
# Attributes:
#     calendar_source:       inferred:range_intersection
#     feature_order_source:  inferred

# %%
print(cube)
print()
print(cube.coords.get("symbol").values)
print()
print(cube.coords.get("feature").values)
print()
print(cube.data_vars.get("values"))
print()
# Out:
# <xarray.Dataset> Size: 501MB
# Dimensions:  (feature: 9, time: 2662909, symbol: 4)
# Coordinates:
#   * feature  (feature) <U13 468B 'Open' 'High' ... 'TakerBuyQuote'
#   * symbol   (symbol) object 32B 'BTCUSDT' 'ETHUSDT' 'BNBUSDT' 'SOLUSDT'
#   * time     (time) datetime64[ns] 21MB 2020-08-11T06:00:00 ... 2025-09-04T11...
# Data variables:
#     mask     (time, symbol, feature) bool 96MB dask.array<chunksize=(16384, 4, 9), meta=np.ndarray>
#     values   (time, symbol, feature) float32 383MB dask.array<chunksize=(16384, 4, 9), meta=np.ndarray>
# Attributes:
#     calendar_source:       inferred:range_intersection
#     feature_order_source:  inferred
#
# ['BTCUSDT' 'ETHUSDT' 'BNBUSDT' 'SOLUSDT']
#
# ['Open' 'High' 'Low' 'Close' 'Volume' 'QuoteVolume' 'Trades'
#  'TakerBuyBase' 'TakerBuyQuote']
#
# <xarray.DataArray 'values' (time: 2662909, symbol: 4, feature: 9)> Size: 383MB
# dask.array<open_dataset-values, shape=(2662909, 4, 9), dtype=float32, chunksize=(16384, 4, 9), chunktype=numpy.ndarray>
# Coordinates:
#   * feature  (feature) <U13 468B 'Open' 'High' ... 'TakerBuyQuote'
#   * symbol   (symbol) object 32B 'BTCUSDT' 'ETHUSDT' 'BNBUSDT' 'SOLUSDT'
#   * time     (time) datetime64[ns] 21MB 2020-08-11T06:00:00 ... 2025-09-04T11...

# %%
import xarray as xr

# giả sử bạn đã có raw cube trong biến `cube`
values = cube["values"]

# 1) mask NaN (lazy, vẫn dùng dask)
nan_mask = values.isnull()

# 2) Tổng số ô NaN toàn cube (tất cả feature)
total_nan = int(nan_mask.sum().compute())
print("Tổng số ô NaN:", total_nan)

# 3) NaN theo symbol (gộp mọi feature, đếm số time-step bị NaN)
nan_by_symbol = nan_mask.any("feature").sum("time").compute()
print("NaN theo symbol:\n", nan_by_symbol)

# 4) Thời điểm nào có NaN ở từng symbol (lọc toàn bộ feature cùng lúc)
nan_time_symbol = nan_mask.any("feature").compute()

# lấy danh sách (time, symbol) có NaN
nan_df = nan_time_symbol.to_dataframe(name="has_nan").query("has_nan")
print("Các time/symbol có NaN:\n", nan_df)

# 5) Nếu muốn soi cả feature nào bị NaN tại những vị trí này:
with_feature = nan_mask.sel(time=nan_df.index.get_level_values("time").unique()).compute()
feature_df = with_feature.to_dataframe(name="is_nan").query("is_nan")
print("Chi tiết feature bị NaN:\n", feature_df)
# Out:
# Tổng số ô NaN: 27
# NaN theo symbol:
#  <xarray.DataArray 'values' (symbol: 4)> Size: 32B
# array([1, 1, 1, 0])
# Coordinates:
#   * symbol   (symbol) object 32B 'BTCUSDT' 'ETHUSDT' 'BNBUSDT' 'SOLUSDT'
# Các time/symbol có NaN:
#                               has_nan
# time                symbol
# 2021-04-25 04:01:00 BTCUSDT     True
#                     ETHUSDT     True
#                     BNBUSDT     True
# Chi tiết feature bị NaN:
#                                             is_nan
# time                symbol  feature
# 2021-04-25 04:01:00 BTCUSDT Open             True
#                             High             True
#                             Low              True
#                             Close            True
#                             Volume           True
#                             QuoteVolume      True
#                             Trades           True
#                             TakerBuyBase     True
#                             TakerBuyQuote    True
#                     ETHUSDT Open             True
#                             High             True
#                             Low              True
#                             Close            True
#                             Volume           True
#                             QuoteVolume      True
#                             Trades           True
#                             TakerBuyBase     True
#                             TakerBuyQuote    True
#                     BNBUSDT Open             True
#                             High             True
#                             Low              True
#                             Close            True
#                             Volume           True
#                             QuoteVolume      True
#                             Trades           True
#                             TakerBuyBase     True
#                             TakerBuyQuote    True

# %%
import xarray as xr
import numpy as np
import pandas as pd

# === CONFIG ===
LABEL_ZARR = "../../../work/processed/binance/data/zarr_cube_label"
GROUP      = "labels"
RET_EPS    = 5e-5  # epsilon để phân loại returns: >eps pos, |r|<=eps zero, <-eps neg

# === LOAD ===
ds_lbl = xr.open_zarr(LABEL_ZARR, group=GROUP)
values = ds_lbl["values"]            # (time, symbol, label)
labels = list(map(str, ds_lbl["label"].values))
symbols = list(map(str, ds_lbl["symbol"].values))
time = ds_lbl["time"].values
print(f"Loaded labels cube: values{tuple(values.shape)} | symbols={symbols[:8]} ... | n_labels={len(labels)}")
# Out:
# Loaded labels cube: values(2662909, 4, 8) | symbols=['BTCUSDT', 'ETHUSDT', 'BNBUSDT', 'SOLUSDT'] ... | n_labels=8

# %%
# giả sử bạn đã chạy khối ở trên và có `values`, `symbols`, `labels`
nan_mask = values.isnull()

total_nan = int(nan_mask.sum().compute())
print("Tổng ô NaN:", total_nan)

nan_by_symbol = nan_mask.any("label").sum("time").compute()
nan_by_label = nan_mask.any("symbol").sum("time").compute()
print("NaN theo symbol:\n", nan_by_symbol)
print("NaN theo label:\n", nan_by_label)

nan_time_symbol = nan_mask.any("label").compute()
nan_df = nan_time_symbol.to_dataframe(name="has_nan").query("has_nan")
print("Các time/symbol có NaN:\n", nan_df)

if not nan_df.empty:
    subset = nan_mask.sel(time=nan_df.index.get_level_values("time").unique()).compute()
    feature_df = subset.to_dataframe(name="is_nan").query("is_nan")
    print("Chi tiết label bị NaN:\n", feature_df)
else:
    print("Không có NaN trong cube label.")
# Out:
# Tổng ô NaN: 402
# NaN theo symbol:
#  <xarray.DataArray 'values' (symbol: 4)> Size: 32B
# array([83, 77, 77, 60])
# Coordinates:
#   * symbol   (symbol) object 32B 'BTCUSDT' 'ETHUSDT' 'BNBUSDT' 'SOLUSDT'
# NaN theo label:
#  <xarray.DataArray 'values' (label: 8)> Size: 64B
# array([ 3, 17,  7, 62, 22,  0,  0,  0])
# Coordinates:
#   * label    (label) object 64B 'ret_log__H1' 'ret_log__H15' ... 'tb_t_hit__H60'
# Các time/symbol có NaN:
#                               has_nan
# time                symbol
# 2021-04-25 03:01:00 BTCUSDT     True
#                     ETHUSDT     True
#                     BNBUSDT     True
# 2021-04-25 03:37:00 BTCUSDT     True
# 2021-04-25 03:39:00 BTCUSDT     True
# ...                              ...
# 2025-09-04 11:51:00 SOLUSDT     True
# 2025-09-04 11:52:00 BTCUSDT     True
#                     ETHUSDT     True
#                     BNBUSDT     True
#                     SOLUSDT     True
#
# [297 rows x 1 columns]
# Chi tiết label bị NaN:
#                                                is_nan
# time                symbol  label
# 2021-04-25 03:01:00 BTCUSDT ret_log__H60        True
#                     ETHUSDT ret_log__H60        True
#                     BNBUSDT ret_log__H60        True
# 2021-04-25 03:37:00 BTCUSDT tb_exit_ret__H60    True
# 2021-04-25 03:39:00 BTCUSDT tb_exit_ret__H60    True
# ...                                              ...
# 2025-09-04 11:52:00 BNBUSDT ret_log__H60        True
#                     SOLUSDT ret_log__H1         True
#                             ret_log__H15        True
#                             ret_log__H5         True
#                             ret_log__H60        True
#
# [402 rows x 1 columns]

# %%
import pandas as pd

nan_df = (
    values.isnull()
    .to_dataframe(name="is_nan")
    .query("is_nan")
    .reset_index()
    .drop(columns="is_nan")
)

# 1) Gom theo (time, symbol) để xem mỗi cây nến thiếu label nào
time_symbol_view = (
    nan_df.groupby(["time", "symbol"])["label"]
    .agg(lambda labels: ", ".join(sorted(labels)))
    .reset_index(name="nan_labels")
    .sort_values(["time", "symbol"])
)

print("Danh sách rút gọn (time, symbol -> nhãn NaN):")
print(time_symbol_view.head(20))

# 2) Nếu muốn gom thuần theo time (bỏ symbol) để xem nến nào bị ảnh hưởng
time_view = (
    nan_df.groupby("time")
    .agg(
        symbols=("symbol", lambda s: ", ".join(sorted(set(s)))),
        labels=("label", lambda lbl: ", ".join(sorted(set(lbl)))),
        n_entries=("label", "size"),
    )
    .reset_index()
    .sort_values("time")
)

print("\nCác timestamp bị NaN và tổng số entries NaN:")
print(time_view.head(20))

# 3) Loại bỏ các NaN do mép horizon (ví dụ ret_log__H60 ở đầu/cuối)
#    Giữ lại phần nghi ngờ quanh candle miss để check thủ công
core_view = time_symbol_view[
    ~time_symbol_view["nan_labels"].str.contains("ret_log")
    | (time_symbol_view["time"] == pd.Timestamp("2021-04-25 03:01:00"))
]


print("\nSubset nghi ngờ do candle miss:")
print(core_view)
# Out:
# Danh sách rút gọn (time, symbol -> nhãn NaN):
#                   time   symbol                      nan_labels
# 0  2021-04-25 03:01:00  BNBUSDT                    ret_log__H60
# 1  2021-04-25 03:01:00  BTCUSDT                    ret_log__H60
# 2  2021-04-25 03:01:00  ETHUSDT                    ret_log__H60
# 3  2021-04-25 03:37:00  BTCUSDT                tb_exit_ret__H60
# 4  2021-04-25 03:39:00  BTCUSDT                tb_exit_ret__H60
# 5  2021-04-25 03:41:00  BTCUSDT                tb_exit_ret__H60
# 6  2021-04-25 03:42:00  BTCUSDT                tb_exit_ret__H60
# 7  2021-04-25 03:44:00  BTCUSDT                tb_exit_ret__H60
# 8  2021-04-25 03:45:00  BTCUSDT                tb_exit_ret__H60
# 9  2021-04-25 03:46:00  BNBUSDT  ret_log__H15, tb_exit_ret__H60
# 10 2021-04-25 03:46:00  BTCUSDT  ret_log__H15, tb_exit_ret__H60
# 11 2021-04-25 03:46:00  ETHUSDT  ret_log__H15, tb_exit_ret__H60
# 12 2021-04-25 03:47:00  BNBUSDT                tb_exit_ret__H60
# 13 2021-04-25 03:47:00  BTCUSDT                tb_exit_ret__H60
# 14 2021-04-25 03:47:00  ETHUSDT                tb_exit_ret__H60
# 15 2021-04-25 03:48:00  BNBUSDT                tb_exit_ret__H60
# 16 2021-04-25 03:48:00  BTCUSDT                tb_exit_ret__H60
# 17 2021-04-25 03:48:00  ETHUSDT                tb_exit_ret__H60
# 18 2021-04-25 03:49:00  BNBUSDT                tb_exit_ret__H60
# 19 2021-04-25 03:49:00  BTCUSDT                tb_exit_ret__H60
#
# Các timestamp bị NaN và tổng số entries NaN:
#                   time                    symbols  \
# 0  2021-04-25 03:01:00  BNBUSDT, BTCUSDT, ETHUSDT
# 1  2021-04-25 03:37:00                    BTCUSDT
# 2  2021-04-25 03:39:00                    BTCUSDT
# 3  2021-04-25 03:41:00                    BTCUSDT
# 4  2021-04-25 03:42:00                    BTCUSDT
# 5  2021-04-25 03:44:00                    BTCUSDT
# 6  2021-04-25 03:45:00                    BTCUSDT
# 7  2021-04-25 03:46:00  BNBUSDT, BTCUSDT, ETHUSDT
# 8  2021-04-25 03:47:00  BNBUSDT, BTCUSDT, ETHUSDT
# 9  2021-04-25 03:48:00  BNBUSDT, BTCUSDT, ETHUSDT
# 10 2021-04-25 03:49:00  BNBUSDT, BTCUSDT, ETHUSDT
# 11 2021-04-25 03:50:00  BNBUSDT, BTCUSDT, ETHUSDT
# 12 2021-04-25 03:51:00  BNBUSDT, BTCUSDT, ETHUSDT
# 13 2021-04-25 03:52:00  BNBUSDT, BTCUSDT, ETHUSDT
# 14 2021-04-25 03:53:00  BNBUSDT, BTCUSDT, ETHUSDT
# 15 2021-04-25 03:54:00  BNBUSDT, BTCUSDT, ETHUSDT
# 16 2021-04-25 03:55:00  BNBUSDT, BTCUSDT, ETHUSDT
# 17 2021-04-25 03:56:00  BNBUSDT, BTCUSDT, ETHUSDT
# 18 2021-04-25 03:57:00  BNBUSDT, BTCUSDT, ETHUSDT
# 19 2021-04-25 03:58:00  BNBUSDT, BTCUSDT, ETHUSDT
#
#                             labels  n_entries
# 0                     ret_log__H60          3
# 1                 tb_exit_ret__H60          1
# 2                 tb_exit_ret__H60          1
# 3                 tb_exit_ret__H60          1
# 4                 tb_exit_ret__H60          1
# 5                 tb_exit_ret__H60          1
# 6                 tb_exit_ret__H60          1
# 7   ret_log__H15, tb_exit_ret__H60          6
# 8                 tb_exit_ret__H60          3
# 9                 tb_exit_ret__H60          3
# 10                tb_exit_ret__H60          3
# 11                tb_exit_ret__H60          3
# 12                tb_exit_ret__H60          3
# 13                tb_exit_ret__H60          3
# 14                tb_exit_ret__H60          3
# 15                tb_exit_ret__H60          3
# 16                tb_exit_ret__H60          3
# 17   ret_log__H5, tb_exit_ret__H60          6
# 18                tb_exit_ret__H60          3
# 19                tb_exit_ret__H60          3
#
# Subset nghi ngờ do candle miss:
#                   time   symbol        nan_labels
# 0  2021-04-25 03:01:00  BNBUSDT      ret_log__H60
# 1  2021-04-25 03:01:00  BTCUSDT      ret_log__H60
# 2  2021-04-25 03:01:00  ETHUSDT      ret_log__H60
# 3  2021-04-25 03:37:00  BTCUSDT  tb_exit_ret__H60
# 4  2021-04-25 03:39:00  BTCUSDT  tb_exit_ret__H60
# 5  2021-04-25 03:41:00  BTCUSDT  tb_exit_ret__H60
# 6  2021-04-25 03:42:00  BTCUSDT  tb_exit_ret__H60
# 7  2021-04-25 03:44:00  BTCUSDT  tb_exit_ret__H60
# 8  2021-04-25 03:45:00  BTCUSDT  tb_exit_ret__H60
# 12 2021-04-25 03:47:00  BNBUSDT  tb_exit_ret__H60
# 13 2021-04-25 03:47:00  BTCUSDT  tb_exit_ret__H60
# 14 2021-04-25 03:47:00  ETHUSDT  tb_exit_ret__H60
# 15 2021-04-25 03:48:00  BNBUSDT  tb_exit_ret__H60
# 16 2021-04-25 03:48:00  BTCUSDT  tb_exit_ret__H60
# 17 2021-04-25 03:48:00  ETHUSDT  tb_exit_ret__H60
# 18 2021-04-25 03:49:00  BNBUSDT  tb_exit_ret__H60
# 19 2021-04-25 03:49:00  BTCUSDT  tb_exit_ret__H60
# 20 2021-04-25 03:49:00  ETHUSDT  tb_exit_ret__H60
# 21 2021-04-25 03:50:00  BNBUSDT  tb_exit_ret__H60
# 22 2021-04-25 03:50:00  BTCUSDT  tb_exit_ret__H60
# 23 2021-04-25 03:50:00  ETHUSDT  tb_exit_ret__H60
# 24 2021-04-25 03:51:00  BNBUSDT  tb_exit_ret__H60
# 25 2021-04-25 03:51:00  BTCUSDT  tb_exit_ret__H60
# 26 2021-04-25 03:51:00  ETHUSDT  tb_exit_ret__H60
# 27 2021-04-25 03:52:00  BNBUSDT  tb_exit_ret__H60
# 28 2021-04-25 03:52:00  BTCUSDT  tb_exit_ret__H60
# 29 2021-04-25 03:52:00  ETHUSDT  tb_exit_ret__H60
# 30 2021-04-25 03:53:00  BNBUSDT  tb_exit_ret__H60
# 31 2021-04-25 03:53:00  BTCUSDT  tb_exit_ret__H60
# 32 2021-04-25 03:53:00  ETHUSDT  tb_exit_ret__H60
# 33 2021-04-25 03:54:00  BNBUSDT  tb_exit_ret__H60
# 34 2021-04-25 03:54:00  BTCUSDT  tb_exit_ret__H60
# 35 2021-04-25 03:54:00  ETHUSDT  tb_exit_ret__H60
# 36 2021-04-25 03:55:00  BNBUSDT  tb_exit_ret__H60
# 37 2021-04-25 03:55:00  BTCUSDT  tb_exit_ret__H60
# 38 2021-04-25 03:55:00  ETHUSDT  tb_exit_ret__H60
# 42 2021-04-25 03:57:00  BNBUSDT  tb_exit_ret__H60
# 43 2021-04-25 03:57:00  BTCUSDT  tb_exit_ret__H60
# 44 2021-04-25 03:57:00  ETHUSDT  tb_exit_ret__H60
# 45 2021-04-25 03:58:00  BNBUSDT  tb_exit_ret__H60
# 46 2021-04-25 03:58:00  BTCUSDT  tb_exit_ret__H60
# 47 2021-04-25 03:58:00  ETHUSDT  tb_exit_ret__H60
# 48 2021-04-25 03:59:00  BNBUSDT  tb_exit_ret__H60
# 49 2021-04-25 03:59:00  BTCUSDT  tb_exit_ret__H60
# 50 2021-04-25 03:59:00  ETHUSDT  tb_exit_ret__H60

# %%
# === HELPERS ===
def _counts_float(arr: np.ndarray, eps: float = 0.0):
    """arr: 1D float array (NaN allowed). Return dict pos/zero/neg/nan/total."""
    mask = ~np.isnan(arr)
    v = arr[mask]
    if eps == 0.0:
        pos = int((v > 0).sum()); zero = int((v == 0).sum()); neg = int((v < 0).sum())
    else:
        pos = int((v >  eps).sum()); zero = int((np.abs(v) <= eps).sum()); neg = int((v < -eps).sum())
    return dict(total=int(arr.size), nan=int((~mask).sum()), pos=pos, zero=zero, neg=neg)

def summarize_all(ret_eps: float = 0.0) -> pd.DataFrame:
    """Tổng hợp theo từng label (gộp tất cả symbol & time)."""
    rows = []
    for lab in labels:
        arr = values.sel(label=lab).values.ravel()
        # TB vs Returns: TB dùng eps=0, Returns dùng ret_eps
        is_tb = lab.startswith("tb_label__")
        cnt = _counts_float(arr, eps=(0.0 if is_tb else ret_eps))
        cov = 100.0 * (cnt["total"] - cnt["nan"]) / max(1, cnt["total"])
        rows.append(dict(label=lab, coverage_pct=round(cov,2), **cnt))
    df = pd.DataFrame(rows).sort_values(["label"]).reset_index(drop=True)
    return df

def summarize_by_symbol(ret_eps: float = 0.0) -> pd.DataFrame:
    """Tổng hợp theo từng (symbol, label)."""
    rows = []
    for sym in symbols:
        print(f"  - Summarizing symbol {sym} ...")
        v_sym = values.sel(symbol=sym)
        for lab in labels:
            arr = v_sym.sel(label=lab).values.ravel()
            is_tb = lab.startswith("tb_label__")
            cnt = _counts_float(arr, eps=(0.0 if is_tb else ret_eps))
            cov = 100.0 * (cnt["total"] - cnt["nan"]) / max(1, cnt["total"])
            rows.append(dict(symbol=sym, label=lab, coverage_pct=round(cov,2), **cnt))
    return pd.DataFrame(rows).sort_values(["symbol","label"]).reset_index(drop=True)

# === RUN SUMMARY ===
df_all = summarize_all(ret_eps=RET_EPS)
display(df_all)

# (tuỳ chọn) xem theo từng symbol:
df_sym = summarize_by_symbol(ret_eps=RET_EPS)
display(df_sym)

# === QUICK DESCRIPTIVE cho returns (mean/std/quantiles) ===
def describe_returns(ret_eps: float = 0.0, qs=(0.01,0.05,0.5,0.95,0.99)) -> pd.DataFrame:
    rows = []
    for lab in labels:
        if not lab.startswith("ret_log__H"):
            continue
        arr = values.sel(label=lab).values.astype(float).ravel()
        v = arr[~np.isnan(arr)]
        if v.size == 0:
            continue
        stats = dict(
            label=lab,
            mean=float(v.mean()),
            std=float(v.std()),
            pos_share=float((v > ret_eps).mean()),
            zero_share=float((np.abs(v) <= ret_eps).mean()),
            neg_share=float((v < -ret_eps).mean()),
        )
        q = np.quantile(v, q=qs)
        stats.update({f"q{int(100*qv)}": float(q[i]) for i, qv in enumerate(qs)})
        rows.append(stats)
    return pd.DataFrame(rows).sort_values("label")

df_desc = describe_returns(ret_eps=RET_EPS)
display(df_desc)
# Out:
# Loaded labels cube: values(2662909, 4, 8) | symbols=['BTCUSDT', 'ETHUSDT', 'BNBUSDT', 'SOLUSDT'] ... | n_labels=8
#                 label  coverage_pct     total  nan       pos     zero      neg
# 0         ret_log__H1         100.0  10651636   10   4693535  1286088  4672003
# 1        ret_log__H15         100.0  10651636   66   5218926   305884  5126760
# 2         ret_log__H5         100.0  10651636   26   5085791   539004  5026815
# 3        ret_log__H60         100.0  10651636  246   5330086   158016  5163288
# 4    tb_exit_ret__H60         100.0  10651636   54   4649308   133035  5869239
# 5  tb_label__H60__pct         100.0  10651636    0   4659498    74889  5917249
# 6  tb_label__H60__vol         100.0  10651636    0   5282482     1077  5368077
# 7       tb_t_hit__H60         100.0  10651636    0  10651636        0        0
#   - Summarizing symbol BTCUSDT ...
#   - Summarizing symbol ETHUSDT ...
#   - Summarizing symbol BNBUSDT ...
#   - Summarizing symbol SOLUSDT ...
#      symbol               label  coverage_pct    total  nan      pos    zero  \
# 0   BNBUSDT         ret_log__H1         100.0  2662909    3  1117598  451009
# 1   BNBUSDT        ret_log__H15         100.0  2662909   17  1292967  127975
# 2   BNBUSDT         ret_log__H5         100.0  2662909    7  1242420  218424
# 3   BNBUSDT        ret_log__H60         100.0  2662909   62  1334565   66374
# 4   BNBUSDT    tb_exit_ret__H60         100.0  2662909   16  1182048   58657
# 5   BNBUSDT  tb_label__H60__pct         100.0  2662909    0  1181276   52666
# 6   BNBUSDT  tb_label__H60__vol         100.0  2662909    0  1313411     767
# 7   BNBUSDT       tb_t_hit__H60         100.0  2662909    0  2662909       0
# 8   BTCUSDT         ret_log__H1         100.0  2662909    3  1163656  332891
# 9   BTCUSDT        ret_log__H15         100.0  2662909   17  1304451   65813
# 10  BTCUSDT         ret_log__H5         100.0  2662909    7  1272680  121173
# 11  BTCUSDT        ret_log__H60         100.0  2662909   62  1333729   34314
# 12  BTCUSDT    tb_exit_ret__H60         100.0  2662909   22  1227289   31158
# 13  BTCUSDT  tb_label__H60__pct         100.0  2662909    0  1240410     904
# 14  BTCUSDT  tb_label__H60__vol         100.0  2662909    0  1321015      39
# 15  BTCUSDT       tb_t_hit__H60         100.0  2662909    0  2662909       0
# 16  ETHUSDT         ret_log__H1         100.0  2662909    3  1212313  238619
# 17  ETHUSDT        ret_log__H15         100.0  2662909   17  1317339   49749
# 18  ETHUSDT         ret_log__H5         100.0  2662909    7  1291718   88838
# 19  ETHUSDT        ret_log__H60         100.0  2662909   62  1343088   25562
# 20  ETHUSDT    tb_exit_ret__H60         100.0  2662909   16  1180409   21285
# 21  ETHUSDT  tb_label__H60__pct         100.0  2662909    0  1187664    1419
# 22  ETHUSDT  tb_label__H60__vol         100.0  2662909    0  1322550      51
# 23  ETHUSDT       tb_t_hit__H60         100.0  2662909    0  2662909       0
# 24  SOLUSDT         ret_log__H1         100.0  2662909    1  1199968  263569
# 25  SOLUSDT        ret_log__H15         100.0  2662909   15  1304169   62347
# 26  SOLUSDT         ret_log__H5         100.0  2662909    5  1278973  110569
# 27  SOLUSDT        ret_log__H60         100.0  2662909   60  1318704   31766
# 28  SOLUSDT    tb_exit_ret__H60         100.0  2662909    0  1059562   21935
# 29  SOLUSDT  tb_label__H60__pct         100.0  2662909    0  1050148   19900
# 30  SOLUSDT  tb_label__H60__vol         100.0  2662909    0  1325506     220
# 31  SOLUSDT       tb_t_hit__H60         100.0  2662909    0  2662909       0
#
#         neg
# 0   1094299
# 1   1241950
# 2   1202058
# 3   1261908
# 4   1422188
# 5   1428967
# 6   1348731
# 7         0
# 8   1166359
# 9   1292628
# 10  1269049
# 11  1294804
# 12  1404440
# 13  1421595
# 14  1341855
# 15        0
# 16  1211974
# 17  1295804
# 18  1282346
# 19  1294197
# 20  1461199
# 21  1473826
# 22  1340308
# 23        0
# 24  1199371
# 25  1296378
# 26  1273362
# 27  1312379
# 28  1581412
# 29  1592861
# 30  1337183
# 31        0
#           label      mean       std  pos_share  zero_share  neg_share  \
# 0   ret_log__H1  0.000001  0.001316   0.440640    0.120741   0.438619
# 1  ret_log__H15  0.000018  0.004955   0.489968    0.028717   0.481315
# 2   ret_log__H5  0.000006  0.002910   0.477467    0.050603   0.471930
# 3  ret_log__H60  0.000071  0.009695   0.500412    0.014835   0.484753
#
#          q1        q5       q50       q95       q99
# 0 -0.003663 -0.001719  0.000000  0.001716  0.003686
# 1 -0.014223 -0.006579  0.000000  0.006541  0.014167
# 2 -0.008173 -0.003808  0.000000  0.003793  0.008175
# 3 -0.028342 -0.013283  0.000055  0.013254  0.028352
